# %% [markdown]
# # Heart Disease Prediction

# %%
import pandas as pd # pandas is used to load and manipulate data and for One-Hot Encoding
import numpy as np # numpy is used to calculate the mean and standard deviation
import matplotlib.pyplot as plt # matplotlib is for drawing graphs
import matplotlib.colors as colors
import seaborn as sns # imporve visuals

#_____________________________________
from sklearn.model_selection import train_test_split # split  data into training and testing sets
from sklearn.preprocessing import scale # scale and center data
from sklearn.svm import SVC # this will make a support vector machine for classificaiton
from sklearn.model_selection import GridSearchCV # this will do cross validation
from sklearn.metrics import confusion_matrix # this creates a confusion matrix
from sklearn.metrics import plot_confusion_matrix # draws a confusion matrix
from sklearn.decomposition import PCA # to perform PCA to plot the data

# %%
df_raw = pd.read_csv('./Data/processed.cleveland.data')
df_raw.head()
# Out:
#    63.0  1.0  1.0.1  145.0  233.0  1.0.2  2.0  150.0  0.0  2.3  3.0 0.0.1  \
# 0  67.0  1.0    4.0  160.0  286.0    0.0  2.0  108.0  1.0  1.5  2.0   3.0
# 1  67.0  1.0    4.0  120.0  229.0    0.0  2.0  129.0  1.0  2.6  2.0   2.0
# 2  37.0  1.0    3.0  130.0  250.0    0.0  0.0  187.0  0.0  3.5  3.0   0.0
# 3  41.0  0.0    2.0  130.0  204.0    0.0  2.0  172.0  0.0  1.4  1.0   0.0
# 4  56.0  1.0    2.0  120.0  236.0    0.0  0.0  178.0  0.0  0.8  1.0   0.0
#
#    6.0  0
# 0  3.0  2
# 1  7.0  1
# 2  3.0  0
# 3  3.0  0
# 4  3.0  0

# %%
df_raw.columns = ['age','sex','cp','restbp','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','hd']

# %%
df_raw.head()
# Out:
#     age  sex   cp  restbp   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  67.0  1.0  4.0   160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 1  67.0  1.0  4.0   120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 2  37.0  1.0  3.0   130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 3  41.0  0.0  2.0   130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 4  56.0  1.0  2.0   120.0  236.0  0.0      0.0    178.0    0.0      0.8
#
#    slope   ca thal  hd
# 0    2.0  3.0  3.0   2
# 1    2.0  2.0  7.0   1
# 2    3.0  0.0  3.0   0
# 3    1.0  0.0  3.0   0
# 4    1.0  0.0  3.0   0

# %%
df_raw.dtypes
# Out:
# age        float64
# sex        float64
# cp         float64
# restbp     float64
# chol       float64
# fbs        float64
# restecg    float64
# thalach    float64
# exang      float64
# oldpeak    float64
# slope      float64
# ca          object
# thal        object
# hd           int64
# dtype: object

# %%
df_raw['ca'].unique()
# Out:
# array(['3.0', '2.0', '0.0', '1.0', '?'], dtype=object)

# %%
df_raw['thal'].unique()
# Out:
# array(['3.0', '7.0', '6.0', '?'], dtype=object)

# %%
#misson data
#How many rows contain missing data? With question mark.
df_raw.loc[(df['ca'] =='?') | (df['thal'] =='?')]
# Out:
#       age  sex   cp  restbp   chol  fbs  restecg  thalach  exang  oldpeak  \
# 86   53.0  0.0  3.0   128.0  216.0  0.0      2.0    115.0    0.0      0.0
# 165  52.0  1.0  3.0   138.0  223.0  0.0      0.0    169.0    0.0      0.0
# 191  43.0  1.0  4.0   132.0  247.0  1.0      2.0    143.0    1.0      0.1
# 265  52.0  1.0  4.0   128.0  204.0  1.0      0.0    156.0    1.0      1.0
# 286  58.0  1.0  2.0   125.0  220.0  0.0      0.0    144.0    0.0      0.4
# 301  38.0  1.0  3.0   138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  hd
# 86     1.0  0.0    ?   0
# 165    1.0    ?  3.0   0
# 191    2.0    ?  7.0   1
# 265    2.0  0.0    ?   2
# 286    2.0    ?  7.0   0
# 301    1.0    ?  3.0   0

# %%
df_raw
# Out:
#       age  sex   cp  restbp   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    67.0  1.0  4.0   160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 1    67.0  1.0  4.0   120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 2    37.0  1.0  3.0   130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 3    41.0  0.0  2.0   130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 4    56.0  1.0  2.0   120.0  236.0  0.0      0.0    178.0    0.0      0.8
# ..    ...  ...  ...     ...    ...  ...      ...      ...    ...      ...
# 297  45.0  1.0  1.0   110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 298  68.0  1.0  4.0   144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 299  57.0  1.0  4.0   130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 300  57.0  0.0  2.0   130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 301  38.0  1.0  3.0   138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  hd
# 0      2.0  3.0  3.0   2
# 1      2.0  2.0  7.0   1
# ...

# %%
# Create data frame with clean data
df = df_raw.loc[(df_raw['ca'] != '?') & (df_raw['thal'] != '?')]

print(f"Raw rows:{len(df_raw)}, Clean rows:{len(df)}")
# Out:
# Raw rows:302, Clean rows:296

# %% [markdown]
# - Exportar el dataset procesado.

# %% [markdown]
# ## SVM.
#
# Split data - train.

# %%
# Copiar por valor y no referencia.
# Elimino la columan que quiero predecir.
X = df.drop('hd', axis=1).copy()
X.head()
# Out:
#     age  sex   cp  restbp   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  67.0  1.0  4.0   160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 1  67.0  1.0  4.0   120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 2  37.0  1.0  3.0   130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 3  41.0  0.0  2.0   130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 4  56.0  1.0  2.0   120.0  236.0  0.0      0.0    178.0    0.0      0.8
#
#    slope   ca thal
# 0    2.0  3.0  3.0
# 1    2.0  2.0  7.0
# 2    3.0  0.0  3.0
# 3    1.0  0.0  3.0
# 4    1.0  0.0  3.0

# %%
# Obtengo la columna por predecir.
y= df['hd'].copy()
y.head()
# Out:
# 0    2
# 1    1
# 2    0
# 3    0
# 4    0
# Name: hd, dtype: int64

# %%
X['cp'].unique()
# Out:
# array([4., 3., 2., 1.])

# %%
# One-Hot encoding para pasar la data cateorica a 0 y 1, en términos de columnas.
pd.get_dummies(X, columns=['cp']).head()
# Out:
#     age  sex  restbp   chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0  67.0  1.0   160.0  286.0  0.0      2.0    108.0    1.0      1.5    2.0
# 1  67.0  1.0   120.0  229.0  0.0      2.0    129.0    1.0      2.6    2.0
# 2  37.0  1.0   130.0  250.0  0.0      0.0    187.0    0.0      3.5    3.0
# 3  41.0  0.0   130.0  204.0  0.0      2.0    172.0    0.0      1.4    1.0
# 4  56.0  1.0   120.0  236.0  0.0      0.0    178.0    0.0      0.8    1.0
#
#     ca thal  cp_1.0  cp_2.0  cp_3.0  cp_4.0
# 0  3.0  3.0       0       0       0       1
# 1  2.0  7.0       0       0       0       1
# 2  0.0  3.0       0       0       1       0
# 3  0.0  3.0       0       1       0       0
# 4  0.0  3.0       0       1       0       0

# %%
X_encoded = pd.get_dummies(X, columns=['cp','restecg','slope','thal'])
X_encoded.head()
# Out:
#     age  sex  restbp   chol  fbs  thalach  exang  oldpeak   ca  cp_1.0  ...  \
# 0  67.0  1.0   160.0  286.0  0.0    108.0    1.0      1.5  3.0       0  ...
# 1  67.0  1.0   120.0  229.0  0.0    129.0    1.0      2.6  2.0       0  ...
# 2  37.0  1.0   130.0  250.0  0.0    187.0    0.0      3.5  0.0       0  ...
# 3  41.0  0.0   130.0  204.0  0.0    172.0    0.0      1.4  0.0       0  ...
# 4  56.0  1.0   120.0  236.0  0.0    178.0    0.0      0.8  0.0       0  ...
#
#    cp_4.0  restecg_0.0  restecg_1.0  restecg_2.0  slope_1.0  slope_2.0  \
# 0       1            0            0            1          0          1
# 1       1            0            0            1          0          1
# 2       0            1            0            0          0          0
# 3       0            0            0            1          1          0
# 4       0            1            0            0          1          0
#
#    slope_3.0  thal_3.0  thal_6.0  thal_7.0
# ...

# %%
# Al support vector machine solo le interesará predecir si esta enformo o no.
# Eliminamos los no enfermoss en y como categoría.

y_clean = y>0
y[y_clean] =1
y.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# task7. 
X_train, X_test, y_train, y_test= train_test_split(X,y,random_state=42)
X_train_scaled = scale(X_train)
X_test_scaled = scale(X_test)

# %%
# Preliminar SVM. Construimos el SVM.
clf_svm = SVC(random_state =42)
clf_svm.fit(X_train_scaled, y_train)
# Out:
# SVC(random_state=42)

# %%
# Realizamos predicciones coneste
# Revisamos que tan bien se desempeño el modelo.
plot_confusion_matrix(clf_svm,X_test_scaled,y_test, display_labels=["No have Hearth Disease","Hearth disease"])
# Out:
# c:\Users\alejandro.gl\Documents\Cerebellum\Quantum Computing\env_q\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Optimizamos con Cross Validation
param_grid =[
    {'C':[1,10,100,1000],
    'gamma':[0.001,0.0001],
    'kernel':['rbf']}
    #'kernel':['rbf','linear']}
]

# %%
optimal_params = GridSearchCV(
    SVC(),
    param_grid,
    cv=5,
    verbose=2
)

optimal_params.fit(X_train_scaled, y_train)
optimal_params.best_params_
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# ...

# %%
# Reconstruct SVM.

clf_svm_optimized = SVC(random_state=42, C=10, gamma=0.001)
clf_svm_optimized.fit(X_train_scaled, y_train)
# Out:
# SVC(C=10, gamma=0.001, random_state=42)

# %%
plot_confusion_matrix(clf_svm_optimized,X_test_scaled,y_test, display_labels=["No have Hearth Disease","Hearth disease"])
# Out:
# c:\Users\alejandro.gl\Documents\Cerebellum\Quantum Computing\env_q\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
len(df.columns)
# Out:
# 14

# %%
# Reducir dimensionalidad
pca = PCA(n_components=13)
X_train_pca = pca.fit_transform(X_train_scaled)

# %%
per_var = np.round(pca.explained_variance_ratio_* 100, decimals=1)
per_var
# Out:
# array([23.5, 13. ,  9.1,  8.7,  8.1,  6.9,  6.4,  5.5,  5.2,  4.3,  3.5,
#         3. ,  2.8])

# %%
labels = ['PC'+str(x) for x in range(1, len(per_var)+1)]

# %%
plt.bar(x=range(1,len(per_var)+1), height=per_var, tick_label=labels)
plt.ylabel('Percentage of Explained Variance')
plt.xlabel('Principal Component')
plt.title('Scree Plot')
plt.show()
